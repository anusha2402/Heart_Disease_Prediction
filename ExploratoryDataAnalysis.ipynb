# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.ipynb_checkpoints', 'dataset.csv', 'DataSetAnalysis.ipynb', 'ExploratoryDataAnalysis.ipynb', 'MLmodel.ipynb']

# %%
read_data=pd.read_csv('dataset.csv')
read_data.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
read_data.shape
# Out:
# (303, 14)

# %%
read_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
read_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ### About The Dataset

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(read_data.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
read_data["target"].describe()
# Out:
# count    303.000000
# mean       0.544554
# std        0.498835
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
read_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
read_data["target"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
read_data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ### Categorical Variables in the Dataset
# sex, cp(chest pain), fbs(fasting blood sugar), restecg(resting cardiographic results), exang(excercise induced angina), slope, thal(thalium stress results)

# %% [markdown]
# ### Numeric Variables in Dataset
# age, trestbps(resting blood pressure), chol(serum cholestrol), thalach(maximum heart rate achieved), oldpeak, ca

# %% [markdown]
# ### Exploratory Data Analysis

# %%
read_data['sex'].value_counts()

labels = 'Male', 'Female',
l=list(read_data['sex'].value_counts())
colors = ['gold', 'yellowgreen']
explode = (0, 0) 
# Plot
plt.pie(l, explode=explode, labels=labels, colors=colors, shadow=True, startangle=200,autopct='%1.1f')
plt.show()

# %%
print(read_data.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# exang       0.436757
# cp          0.433798
# oldpeak     0.430696
# thalach     0.421741
# ca          0.391724
# slope       0.345877
# thal        0.344029
# sex         0.280937
# age         0.225439
# trestbps    0.144931
# restecg     0.137230
# chol        0.085239
# fbs         0.028046
# Name: target, dtype: float64

# %% [markdown]
# ### Analysing target

# %%
sns.countplot(x ='target', data = read_data)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# target (yes = 0(>50% chance of having the disease), no=1(<50% chance of having disease))

# %% [markdown]
# ### Analysing 'Sex' feature

# %%
read_data["sex"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.barplot(x = 'sex', y = 'target', data = read_data)
# Out:
# <Axes: xlabel='sex', ylabel='target'>

# %% [markdown]
# ### Analysing Chest Pain

# %%
read_data["cp"].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
sns.countplot(x ='cp', data = read_data)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %% [markdown]
# ### Analysing FBS

# %%
read_data["fbs"].describe()
# Out:
# count    303.000000
# mean       0.148515
# std        0.356198
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fbs, dtype: float64

# %%
sns.barplot(x='fbs',y='target',data=read_data)
# Out:
# <Axes: xlabel='fbs', ylabel='target'>

# %% [markdown]
# ### Analysing restecg

# %%
read_data["restecg"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
sns.barplot(x='restecg',y='target',data=read_data)
# Out:
# <Axes: xlabel='restecg', ylabel='target'>

# %% [markdown]
# ### Analysing exang

# %%
read_data["exang"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.barplot(x='exang',y='target',data=read_data)
# Out:
# <Axes: xlabel='exang', ylabel='target'>

# %% [markdown]
# ### Analysing Slope

# %%
read_data["slope"].unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %%
sns.barplot(x='slope',y='target',data=read_data)
# Out:
# <Axes: xlabel='slope', ylabel='target'>

# %% [markdown]
# ### Analysing ca

# %%
read_data["ca"].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
sns.countplot(x ='ca', data = read_data)
# Out:
# <Axes: xlabel='ca', ylabel='count'>

# %%
sns.barplot(x ='ca',y='target', data = read_data)
# Out:
# <Axes: xlabel='ca', ylabel='target'>

# %% [markdown]
# ### Analysing thal

# %%
read_data["thal"].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
sns.barplot(x ='thal',y='target', data = read_data)
# Out:
# <Axes: xlabel='thal', ylabel='target'>

# %%
sns.distplot(read_data["thal"])
# Out:
# <Axes: xlabel='thal', ylabel='Density'>

# %% [markdown]
# ### Percentage of patients with or without heart problems

# %%
countNoDisease = len(read_data[read_data.target == 1])
countHaveDisease = len(read_data[read_data.target == 0])
print("Percentage of Patients Haven't Heart Disease: {:.2f}%".format((countNoDisease / (len(read_data.target))*100)))
print("Percentage of Patients Have Heart Disease: {:.2f}%".format((countHaveDisease / (len(read_data.target))*100)))
# Out:
# Percentage of Patients Haven't Heart Disease: 54.46%
# Percentage of Patients Have Heart Disease: 45.54%

# %% [markdown]
# ### Heart disease frequency for ages

# %%
pd.crosstab(read_data.age,read_data.target).plot(kind="bar",figsize=(20,6))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Heart disease frequency for male and female

# %%
pd.crosstab(read_data.sex,read_data.target).plot(kind="bar",figsize=(15,6),color=['blue','#AA1111' ])
plt.title('Heart Disease Frequency for Sex')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.xticks(rotation=0)
plt.legend(["Haven't Disease", "Have Disease"])
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Visualising relation of variables with target variable

# %% [markdown]
# ### Age

# %%
plt.title('Age vs Target')
sns.boxplot(x='target',y='age',data=read_data)
# Out:
# <Axes: title={'center': 'Age vs Target'}, xlabel='target', ylabel='age'>

# %% [markdown]
# With only a few outliers, people with heart disease are relatively older.

# %% [markdown]
# ### Gender

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.title('Gender distribution in dataset')
read_data.sex.value_counts().plot.pie(autopct="%0.2f%%",colors=['blue','pink'])
df=read_data.iloc[:,[1,13]]
plt.subplot(122)
df['sex'].replace({1:'male',0:'female'},inplace=True)
plt.title('Gender distribution in target variable')
sns.countplot(x='target',data=df,hue='sex',palette=['blue','pink'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3948\734294871.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sex'].replace({1:'male',0:'female'},inplace=True)
# <Axes: title={'center': 'Gender distribution in target variable'}, xlabel='target', ylabel='count'>

# %% [markdown]
#  We observe that more males have the disease than female. At first,sex seems to be a good predictor as we see that from all those who have the heart disease,around 80% of them are males. Considering the fact that in our dataset higher number of males are there and so the results could be a bias because of more number.

# %% [markdown]
# ### Chest Pain Type

# %%
plt.title('Distribution of chest pain in dataset')
sns.countplot(x='cp',data=read_data,palette=['pink','orange','green','blue'])
plt.figure(figsize=(12,8))
df=read_data.groupby(['target'])['cp'].value_counts()
plt.subplot(131)
explode=(0.1,0,0,0)
df[0].plot.pie(autopct="%0.2f%%",colors=['green','orange','pink','blue'],explode=explode,shadow=True)
plt.title("Distribution of cp when disease isnt present \n target=0")
plt.subplot(133)
plt.title("Distribution of cp when disease is present \n target=1")
explode=(0.1,0,0,0)
df[1].plot.pie(autopct="%0.2f%%",colors=['pink','green','orange','blue'],explode=explode,shadow=True)
# Out:
# <Axes: title={'center': 'Distribution of cp when disease is present \n target=1'}, ylabel='cp'>

# %% [markdown]
# #### ChestPain(cp) type seems to be really good predictor as people with pain type 0(Asymptotic) are at risk while people with type 2(non anginal type) are quite on the safer side.

# %% [markdown]
# ### trestbps

# %%
plt.title('trestbps vs target')
sns.boxplot(x='target',y='trestbps',data=read_data)
# Out:
# <Axes: title={'center': 'trestbps vs target'}, xlabel='target', ylabel='trestbps'>

# %% [markdown]
# #### With a very few outliers, we see that trestbps doesn't vary much with the target.

# %% [markdown]
# ### Chol(serum cholestrol in blood)

# %%
plt.title('chol vs target')
sns.boxplot(x='target',y='chol',data=read_data)
# Out:
# <Axes: title={'center': 'chol vs target'}, xlabel='target', ylabel='chol'>

# %% [markdown]
# Chol doesn't vary much with the target.i.e serum cholestrol level isn't a clear indication of heart disease. We also also observe that few people having cholestrol level >350 are safe while one having chol level around 350 is at risk.(These are the outliers) Chol doesn't vary much with the target.i.e serum cholestrol level isn't a clear indication of heart disease. We also also observe that few people having cholestrol level >350 are safe while one having chol level around 350 is at risk.(These are the outliers)

# %% [markdown]
# ### restecg

# %%
plt.title('Distribution of restecg in dataset')
sns.countplot(x='restecg',data=read_data,palette=['blue','green','orange'])
plt.figure(figsize=(12,8))
df=read_data.groupby(['target'])['restecg'].value_counts()
plt.subplot(131)
explode=(0.1,0,0)
df[0].plot.pie(autopct="%0.2f%%",colors=['green','blue','orange'],explode=explode,shadow=True)
plt.title("Distribution of restecg when target=0")
plt.subplot(133)
plt.title("Distribution of restecg when target=1")
df[1].plot.pie(autopct="%0.2f%%",colors=['blue','green','orange'],explode=explode,shadow=True)
# Out:
# <Axes: title={'center': 'Distribution of restecg when target=1'}, ylabel='restecg'>

# %% [markdown]
# #### restecg seems to be a fairly good predictor as people with type 0 and type 1 have 60%-40% chance of being under risk.

# %% [markdown]
# ### Thalach(maximum heart rate)

# %%
plt.title("Thalach vs target")
sns.boxplot(x='target',y='thalach',data=read_data)
# Out:
# <Axes: title={'center': 'Thalach vs target'}, xlabel='target', ylabel='thalach'>

# %% [markdown]
# #### People with heart disease have relatively lower heart rate. Hence thalach is a good feature to work on.

# %% [markdown]
# ### (exang) exercise induced angina

# %%
plt.title('Distribution of exang(exercise induced angina) in dataset')
sns.countplot(x='exang',data=read_data,palette=['grey','orange'])
df=read_data.groupby(['target'])['exang'].value_counts()
plt.figure(figsize=(12,8))
plt.subplot(131)
plt.title('Distribution of exang in target=0')
df[0].plot.pie(autopct="%0.2f%%",colors=['grey','orange'])
plt.subplot(133)
plt.title('Distribution of exang in target=1')
df[1].plot.pie(autopct="%0.2f%%",colors=['orange','grey'])
# Out:
# <Axes: title={'center': 'Distribution of exang in target=1'}, ylabel='exang'>

# %% [markdown]
# #### Mostly people in our dataset don't have exercise induced angina.
# (exang) exercise induced angina seemed to increase the risk of heart disease with 55% of those who are at risk suffer from exercise induced angina and 86% of diseases free people dont suffer from exercise induced angina

# %% [markdown]
# ### fbs(fasting blood suagar levels)

# %%
plt.title('Distribution of fbs in dataset')
sns.countplot(x='fbs',data=read_data,palette=['grey','orange'])
df=read_data.groupby(['target'])['fbs'].value_counts()
plt.figure(figsize=(12,8))
plt.subplot(131)
plt.title('Distribution of fbs in target=0')
df[0].plot.pie(autopct="%0.2f%%",colors=['grey','orange'])
plt.subplot(133)
plt.title('Distribution of fbs in target=1')
df[1].plot.pie(autopct="%0.2f%%",colors=['grey','orange'])
# Out:
# <Axes: title={'center': 'Distribution of fbs in target=1'}, ylabel='fbs'>

# %% [markdown]
# fbs is not a great predictor as the distribution across target variable is nearly same.

# %% [markdown]
# ### oldpeak

# %%
plt.title('Oldpeak vs target')
sns.boxplot(x='target',y='oldpeak',data=read_data)
# Out:
# <Axes: title={'center': 'Oldpeak vs target'}, xlabel='target', ylabel='oldpeak'>

# %% [markdown]
# People with heart diseases have relatively higher oldpeak value than those not having heart disease. Also a good feature.

# %% [markdown]
# ### slope

# %%
plt.title('distribution of slope in dataset')
sns.countplot(x='slope',data=read_data,palette=['purple','orange','grey'])
df=read_data.groupby(['target'])['slope'].value_counts()
plt.figure(figsize=(12,8))
plt.subplot(131)
plt.title('Distribution of slope in target=0')
explode=(0.1,0,0)
df[0].plot.pie(autopct="%0.2f%%",colors=['orange','grey','purple'],explode=explode,shadow=True)
plt.subplot(133)
plt.title('Distribution of slope in target=1')
df[1].plot.pie(autopct="%0.2f%%",colors=['grey','orange','purple'],explode=explode,shadow=True)
# Out:
# <Axes: title={'center': 'Distribution of slope in target=1'}, ylabel='slope'>

# %% [markdown]
# ### ca(number of major vessels colored by fluoroscopy)

# %%
plt.title('distribution of ca in dataset')
sns.countplot(x='ca',data=read_data,palette=['teal','orange','grey','pink','yellow'])
df=read_data.groupby(['target'])['ca'].value_counts()
plt.figure(figsize=(12,8))
plt.subplot(131)
plt.title('Distribution of ca in target=0')
explode=(0.1,0,0,0,0)
df[0].plot.pie(autopct="%0.2f%%",colors=['teal','orange','grey','pink','yellow'],explode=explode,shadow=True)
plt.subplot(133)
plt.title('Distribution of ca in target=1')
df[1].plot.pie(autopct="%0.2f%%",colors=['teal','orange','grey','pink','yellow'],explode=explode,shadow=True)
# Out:
# <Axes: title={'center': 'Distribution of ca in target=1'}, ylabel='ca'>

# %% [markdown]
# ### Visualising relation of predictor variables with each other

# %% [markdown]
# ### Thalach vs age

# %%
plt.title('Thalach vs age')
sns.scatterplot(x='age',y='thalach',hue='target',data=read_data)
# Out:
# <Axes: title={'center': 'Thalach vs age'}, xlabel='age', ylabel='thalach'>

# %% [markdown]
# ### thalach vs exang

# %%
plt.title('thalach vs exang')
sns.boxplot(x='exang',y='thalach',data=read_data)
# Out:
# <Axes: title={'center': 'thalach vs exang'}, xlabel='exang', ylabel='thalach'>

# %% [markdown]
# We see that people who have exercise induced angina have lower heart rate

# %% [markdown]
# ### Age vs Max heart rate for Herat Disease

# %%
plt.figure(figsize=(10,6))

# scatter with positive examples
plt.scatter(read_data.age[read_data.target==1],
            read_data.thalach[read_data.target==1],
            c="salmon");

# scatter with negative exaples
plt.scatter(read_data.age[read_data.target==0],
            read_data.thalach[read_data.target==0],
            c="lightblue");

plt.title("Heart Disease in function of Age and Max Heart Rate")
plt.xlabel("Age")
plt.ylabel("Max Heart Rate")
plt.legend(["Disease", "No Disease"]);

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Chestpain(cp),exercise induced angina(exang),resting ecg(restecg) ,thal,thalach,slope,ca,oldpeak are good features.

# %% [markdown]
# ### Build a correlation matrix to identify relevant variables

# %%
plt.figure(figsize=(12,8))
plt.title('Correlation between variables')
sns.heatmap(read_data.corr(),annot=True)
# Out:
# <Axes: title={'center': 'Correlation between variables'}>
